# %% [markdown]
# EXPLOATORY DATA ANALYSIS USING PYTHON
# WEATHER DATA ANALYIS
# DATA SET FROM KAGGLE
# Data set is a time-series data set with per-hour information about weather conditions at a particular location.
# It records Temperature, Dew point temperature,Relative Humidity,wind speed,Visibility,Pressure,and Conditions.

# %% [markdown]
# ANALYSIS:
# #Creating a basic profile analysis of overall dataset
#     view result in "EDA_WEATHER.html file"
# #Provide basic information about dataframe: rows,columns,types.
# #shows first N rows in data (by N=15)
# #Find out the different weather conditions available
# #Count the no.of times is diiferent values in the field Weather
# #Find the number of times the weather is clear
# #Find all the Unique wind speed values recorded in the dataset
# #Find the instances when the Visibilty is Lesser than or equal to 5 km  with the Relational humidity is  greater than 60%
# #Find the  wind speed values of Last 5 records
# #Get weather and Temperature columns in the dataframe
# #which were the the top 15 hottest temperatures values and the their counts
# #Get the rows between 20- 50  from the Dataframe
# #what were the pressure values recorded on Jan 6
# #Find all the instances when the weather is Rain and Wind speed is lesser than or equal to 50
# #Get the list of months in which it rained with thunderstorm

# %%
import pandas as pd
import numpy as np
import calendar
import time
from pandas_profiling import ProfileReport

# %%
df=pd.read_csv(r"C:\Users\DELL\Desktop\python\dataanalysis\weather_2012.csv",parse_dates=True,index_col='Date/Time')
df.head()
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-01 02:00:00      -1.8                -3.4           89
# 2012-01-01 03:00:00      -1.5                -3.2           88
# 2012-01-01 04:00:00      -1.5                -3.3           88
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-01 00:00:00                4              8.0           101.24
# 2012-01-01 01:00:00                4              8.0           101.24
# 2012-01-01 02:00:00                7              4.0           101.26
# 2012-01-01 03:00:00                6              4.0           101.27
# 2012-01-01 04:00:00                7              4.8           101.23
#
#                                   Weather
# Date/Time
# 2012-01-01 00:00:00                   Fog
# ...

# %%
#Creating a basic profile analysis of overall dataset
profile=ProfileReport(df,title='EDA WEATHER')
profile.to_file('EDA_WEATHER.html')


#view result in "EDA_WEATHER.html file"
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#provide basic information about the dataframe rows,columns,types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8784 entries, 2012-01-01 00:00:00 to 2012-12-31 23:00:00
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Temp (C)            8784 non-null   float64
#  1   Dew Point Temp (C)  8784 non-null   float64
#  2   Rel Hum (%)         8784 non-null   int64
#  3   Wind Spd (km/h)     8784 non-null   int64
#  4   Visibility (km)     8784 non-null   float64
#  5   Stn Press (kPa)     8784 non-null   float64
#  6   Weather             8784 non-null   object
# dtypes: float64(4), int64(2), object(1)
# memory usage: 549.0+ KB

# %%
#shows first 25 rows in the data (by n=15 ) 
df[:25]
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-01 02:00:00      -1.8                -3.4           89
# 2012-01-01 03:00:00      -1.5                -3.2           88
# 2012-01-01 04:00:00      -1.5                -3.3           88
# 2012-01-01 05:00:00      -1.4                -3.3           87
# 2012-01-01 06:00:00      -1.5                -3.1           89
# 2012-01-01 07:00:00      -1.4                -3.6           85
# 2012-01-01 08:00:00      -1.4                -3.6           85
# 2012-01-01 09:00:00      -1.3                -3.1           88
# 2012-01-01 10:00:00      -1.0                -2.3           91
# 2012-01-01 11:00:00      -0.5                -2.1           89
# 2012-01-01 12:00:00      -0.2                -2.0           88
# 2012-01-01 13:00:00       0.2                -1.7           87
# ...

# %%
#Find out the different weather conditions available
df['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
#Count the no.of values where there is different values in the field Weather
df['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
#Find the number of times the weather is clear
len(df[df. Weather=='Clear'])
# Out:
# 1326

# %%
#Find all the Unique wind speed values recorded in the dataset
df['Wind Spd (km/h)'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
#Find the instances when the Visibilty is Lesser than or equal to 5 km  with the Relational humidity is  greater than 60%
df[(df['Rel Hum (%)'] > 60) & (df['Visibility (km)'] <= 5.0)]
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 02:00:00      -1.8                -3.4           89
# 2012-01-01 03:00:00      -1.5                -3.2           88
# 2012-01-01 04:00:00      -1.5                -3.3           88
# 2012-01-01 09:00:00      -1.3                -3.1           88
# 2012-01-01 10:00:00      -1.0                -2.3           91
# ...                       ...                 ...          ...
# 2012-12-30 03:00:00      -9.1               -10.4           90
# 2012-12-30 05:00:00      -9.1               -10.4           90
# 2012-12-31 08:00:00      -8.6               -10.3           87
# 2012-12-31 09:00:00      -8.1                -9.6           89
# 2012-12-31 21:00:00      -0.5                -1.5           93
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-01 02:00:00                7              4.0           101.26
# ...

# %%
#Find the  wind speed values of Last 5 records
df['Wind Spd (km/h)'].tail()
# Out:
# Date/Time
# 2012-12-31 19:00:00    30
# 2012-12-31 20:00:00    24
# 2012-12-31 21:00:00    28
# 2012-12-31 22:00:00    28
# 2012-12-31 23:00:00    30
# Name: Wind Spd (km/h), dtype: int64

# %%
#Get only weather and Temperature columns in the dataframe
df[['Weather','Temp (C)']]
# Out:
#                                   Weather  Temp (C)
# Date/Time
# 2012-01-01 00:00:00                   Fog      -1.8
# 2012-01-01 01:00:00                   Fog      -1.8
# 2012-01-01 02:00:00  Freezing Drizzle,Fog      -1.8
# 2012-01-01 03:00:00  Freezing Drizzle,Fog      -1.5
# 2012-01-01 04:00:00                   Fog      -1.5
# ...                                   ...       ...
# 2012-12-31 19:00:00                  Snow       0.1
# 2012-12-31 20:00:00                  Snow       0.2
# 2012-12-31 21:00:00                  Snow      -0.5
# 2012-12-31 22:00:00                  Snow      -0.2
# 2012-12-31 23:00:00                  Snow       0.0
#
# [8784 rows x 2 columns]

# %%
#which were the the top 15 hottest temperatures values and the their counts 
df['Temp (C)'].value_counts().sort_values(ascending=False).head(15)
# Out:
#  16.6    65
#  1.1     58
#  0.8     47
#  1.5     45
#  19.3    44
#  21.1    43
#  2.6     43
#  0.4     41
#  1.3     40
#  14.6    39
#  8.4     38
#  1.0     38
#  1.8     38
# -4.3     37
#  13.1    37
# Name: Temp (C), dtype: int64

# %%
#Get the rows between 20- 50  from the Dataframe
df[20:50]
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 20:00:00       3.2                 1.3           87
# 2012-01-01 21:00:00       4.0                 1.7           85
# 2012-01-01 22:00:00       4.4                 1.9           84
# 2012-01-01 23:00:00       5.3                 2.0           79
# 2012-02-01 00:00:00       5.2                 1.5           77
# 2012-02-01 01:00:00       4.6                 0.0           72
# 2012-02-01 02:00:00       3.9                -0.9           71
# 2012-02-01 03:00:00       3.7                -1.5           69
# 2012-02-01 04:00:00       2.9                -2.3           69
# 2012-02-01 05:00:00       2.6                -2.3           70
# 2012-02-01 06:00:00       2.3                -2.6           70
# 2012-02-01 07:00:00       2.0                -2.9           70
# 2012-02-01 08:00:00       1.9                -3.3           68
# 2012-02-01 09:00:00       1.8                -3.7           67
# ...

# %%
#what were the pressure values recorded on Jan 6
df.loc['2012-01-06','Stn Press (kPa)']
# Out:
# Date/Time
# 2012-01-06 00:00:00    101.21
# 2012-01-06 01:00:00    101.24
# 2012-01-06 02:00:00    101.27
# 2012-01-06 03:00:00    101.29
# 2012-01-06 04:00:00    101.34
# 2012-01-06 05:00:00    101.38
# 2012-01-06 06:00:00    101.42
# 2012-01-06 07:00:00    101.44
# 2012-01-06 08:00:00    101.48
# 2012-01-06 09:00:00    101.47
# 2012-01-06 10:00:00    101.44
# 2012-01-06 11:00:00    101.40
# 2012-01-06 12:00:00    101.32
# 2012-01-06 13:00:00    101.29
# 2012-01-06 14:00:00    101.21
# 2012-01-06 15:00:00    101.16
# 2012-01-06 16:00:00    101.04
# 2012-01-06 17:00:00    101.03
# 2012-01-06 18:00:00    100.98
# 2012-01-06 19:00:00    100.88
# 2012-01-06 20:00:00    100.86
# 2012-01-06 21:00:00    100.80
# 2012-01-06 22:00:00    100.77
# 2012-01-06 23:00:00    100.77
# Name: Stn Press (kPa), dtype: float64

# %%
#Find all the instances when the weather is Rain and Wind speed is lesser than or equal to 50
df[(df['Weather']== 'Rain') & (df['Wind Spd (km/h)']<= 50)]
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 18:00:00       3.8                 1.0           82
# 2012-01-01 19:00:00       3.1                 1.3           88
# 2012-01-23 14:00:00       2.7                -1.1           76
# 2012-01-23 15:00:00       2.7                -0.9           77
# 2012-01-23 17:00:00       3.1                -0.4           78
# ...                       ...                 ...          ...
# 2012-12-21 17:00:00       1.3                 0.2           92
# 2012-12-21 18:00:00       1.4                 0.3           92
# 2012-12-21 19:00:00       2.3                 1.1           92
# 2012-12-21 20:00:00       2.4                 1.7           95
# 2012-12-21 21:00:00       1.3                 0.4           94
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Weather
# Date/Time
# 2012-01-01 18:00:00               15             12.9            99.74    Rain
# ...

# %%
#what is the mean temperature recorded by month
mean_temperatures={}

for month in range(1,13):
    mean_temperatures[month]=df.loc[df.index.month==month,'Temp (C)'].mean()

pd.Series(mean_temperatures)
# Out:
# 1     -1.638844
# 2      1.971408
# 3      7.177688
# 4      8.286250
# 5     14.339382
# 6     16.144861
# 7     17.567070
# 8     16.817742
# 9     11.917639
# 10     9.844489
# 11     2.546389
# 12     0.282661
# dtype: float64

# %%
#using Pivot table
mean_temperature_df=df.pivot_table(values='Temp (C)',index=df.index.month,aggfunc=np.mean)
mean_temperature_df
# Out:
#             Temp (C)
# Date/Time
# 1          -1.638844
# 2           1.971408
# 3           7.177688
# 4           8.286250
# 5          14.339382
# 6          16.144861
# 7          17.567070
# 8          16.817742
# 9          11.917639
# 10          9.844489
# 11          2.546389
# 12          0.282661

# %%
#Extract month name from the date and store in new column named as month
df['month']=df.index.month
df['month']=df['month'].apply(lambda x:calendar.month_name[x])
df[20:65]
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 20:00:00       3.2                 1.3           87
# 2012-01-01 21:00:00       4.0                 1.7           85
# 2012-01-01 22:00:00       4.4                 1.9           84
# 2012-01-01 23:00:00       5.3                 2.0           79
# 2012-02-01 00:00:00       5.2                 1.5           77
# 2012-02-01 01:00:00       4.6                 0.0           72
# 2012-02-01 02:00:00       3.9                -0.9           71
# 2012-02-01 03:00:00       3.7                -1.5           69
# 2012-02-01 04:00:00       2.9                -2.3           69
# 2012-02-01 05:00:00       2.6                -2.3           70
# 2012-02-01 06:00:00       2.3                -2.6           70
# 2012-02-01 07:00:00       2.0                -2.9           70
# 2012-02-01 08:00:00       1.9                -3.3           68
# 2012-02-01 09:00:00       1.8                -3.7           67
# ...

# %%
#Get the list of months in which it rained with thunderstorm
def checkList(x):
    weatherList=['rain', 'thunderstorms']
    count=0
    for substring in weatherList:
        if substring in x:
                        count+=1;
    if (count==2):
        return True
    else:
        return False

print(" Get the list of months it rained with Thunder storms\n")

rained=df['Weather'].str.lower().apply(checkList)
month_list=df[rained]['month'].unique()
print(month_list)
# Out:
#  Get the list of months it rained with Thunder storms
#
# ['May' 'June' 'April' 'July' 'November' 'August' 'September']
